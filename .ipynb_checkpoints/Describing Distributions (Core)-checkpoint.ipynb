# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('data/medical_data.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               995 non-null    object
#  1   Lat                 1000 non-null   float64
#  2   Lng                 1000 non-null   float64
#  3   Area                995 non-null    object
#  4   Children            993 non-null    float64
#  5   Age                 1000 non-null   int64
#  6   Income              1000 non-null   float64
#  7   Marital             995 non-null    object
#  8   Gender              995 non-null    object
#  9   ReAdmis             1000 non-null   int64
#  10  VitD_levels         1000 non-null   float64
#  11  Doc_visits          1000 non-null   int64
#  12  Full_meals_eaten    1000 non-null   int64
#  13  vitD_supp           1000 non-null   int64
#  14  Soft_drink          1000 non-null   int64
# ...

# %% [markdown]
# # Features to Analyze

# %% [markdown]
# ### VitD_levels

# %%
# Plot a histogram with a kde (kernel density estimate)

# Plot and standardize for use with other variables
col = 'VitD_levels'
feature = df[col]
sns.kdeplot(feature);

# %%
# Add a line for the mean (red)
# Add a line for the median (green)

# Assign values for mean and median
mean = feature.mean()
median = feature.median()


# Replot with lines
fig,ax = plt.subplots(figsize=(12,8))
sns.kdeplot(feature)
ax.axvline(mean, color= 'red')
ax.axvline(median, color='green');

# %%
# Add a line for for +1 std from the mean (black)
# Add a line for the - 1 std from the mean (black)
# Highlight the range between +1 and =1 std (yellow)

# Assign values for one std above and below mean
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

# %%
# Replot with better labeling
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(12,8))
sns.kdeplot(feature, ax=ax)
ax.axvline(mean, color= 'red', label=f'mean = {mean:,.2f}')
ax.axvline(median, color='green', label=f'median = {median:,.2f}')
# Lines for std's
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
# highlight range betweem std's
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### Doc_visits

# %%
# Copy above graph for 'Doc_visits'
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(12,8))
sns.kdeplot(feature, ax=ax)
ax.axvline(mean, color= 'red', label=f'mean = {mean:,.2f}')
ax.axvline(median, color='green', label=f'median = {median:,.2f}')
# Lines for std's
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
# highlight range betweem std's
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### TotalCharge

# %%
# Copy above graph for 'TotalCharge'
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(12,8))
sns.kdeplot(feature, ax=ax)
ax.axvline(mean, color= 'red', label=f'mean = {mean:,.2f}')
ax.axvline(median, color='green', label=f'median = {median:,.2f}')
# Lines for std's
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
# highlight range betweem std's
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# # Answer the Following:

# %% [markdown]
# ### 1. Is it Discrete or Continuous?

# %% [markdown]
# #### VitD_levels

# %%
# VitD_levels

df.loc[:,['VitD_levels']].head()
# Out:
#    VitD_levels
# 0    19.141466
# 1    18.940352
# 2    18.057507
# 3    16.576858
# 4    17.439069

# %%
df.loc[:,['VitD_levels']].hist();

# %% [markdown]
# #### Doc_visits

# %%
# Doc_visits

df.loc[:,['Doc_visits']].head()
# Out:
#    Doc_visits
# 0           6
# 1           4
# 2           4
# 3           4
# 4           5

# %%
df.loc[:,['Doc_visits']].hist();

# %% [markdown]
# #### TotalCharge

# %%
# TotalCharge

df.loc[:,['TotalCharge']].head()
# Out:
#    TotalCharge
# 0  3726.702860
# 1  4193.190458
# 2  2434.234222
# 3  2127.830423
# 4  2113.073274

# %%
df.loc[:,['TotalCharge']].hist();

# %% [markdown]
# - Of the mentioned features, VitD_levels and TotalCharge seem to be considered continuous as they can nearly take on infinite number of values. Another telltale sign of this is how the visuals for these columns do NOT contain gaps in between the histogram bars.

# %% [markdown]
# - Doc_visits on the other hand does contain gaps within the histogram bars, making it a discrete distribution.

# %% [markdown]
# ### 2. Does it have a skew? If so, which direction (+/-)

# %% [markdown]
# VitD_levels feature has nearly symmetrical mean and median. Due to this, it would be considered to be a normal curve.

# %% [markdown]
# Doc_visits feature has nearly symmetrical mean and median. Due to this, it would be considered to be a normal curve.

# %% [markdown]
# TotalCharge feature seems to display a positive skew for the following reasons.
# - The median is smaller than the mean
# - The right tail end of the distribution is longer in comparison to the left

# %% [markdown]
# ### 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %% [markdown]
# Using the Pearson calculation:
#
# - Mesokurtic (Kurtosis ~3)
#
# - Leptokurtic (Kurtosis >3)
#
# - Platykurtic (Kurtosis < 3)

# %% [markdown]
# Mesokurtic (values cluster in the middle of the distribution - normal)
#
# Leptokurtic ("pointy", values cluster in the peak of the distribution - positive)
#
# Platykurtic ("flat", values cluster in the tails of the distribution - negative)

# %%
# VitD_levels

kurt_VitD = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt_VitD
# Out:
# 3.013147515833447

# %% [markdown]
# VitD_levels displays Mesokurtic

# %%
# Doc_visits

kurt_Doc = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt_Doc
# Out:
# 2.9919958083381206

# %% [markdown]
# Doc_visits displays Mesokurtic

# %%
# TotalCharge

kurt_Total = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt_Total
# Out:
# 3.2650077463439384

# %% [markdown]
# TotalCharge displays Leptokurtic
# - Leptokurtic refers to the "pointy" feature the curve would present
# - Values would cluster in the peak of the distribution
